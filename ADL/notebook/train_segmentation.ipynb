# %%
import sys
sys.path.append("/home/alisa/git/AstroDeepLearning/")
from ADL.model.scripts import train_Planck_Unet
import tensorflow as tf

# %% [markdown]
# ## Обучение модели сегментации

# %%
name = "pz-not-cluster_8-8"
dataset = "pz-not-cluster"
old_version = False
model_prms={"equal_filters": False, "input_shape": (64, 64, 6), "n_filters": 8, "n_blocks": 5, "weights": None, "n_classes": 2}
epochs = 140
batch_size = 150
lrdict = None
add_LFI = None
train_Planck_Unet(name, "/home/alisa/Data/Planck/healpix_nside2/", 
                  f"/home/alisa/Data/Planck/datasets/{dataset}/",
                  f"/home/alisa/Models/Planck_Unet/{name}", pixels="default", 
                  batch_size=batch_size, epochs=epochs, device="gpu", continue_train=False, 
                  lr_scheduler=lrdict, save_best_only=True, test_as_val = True, 
                  old_version=old_version, model_prms=model_prms,
                  add_LFI=add_LFI)
# Out:
# /home/alisa/.local/lib/python3.9/site-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch #0
#     554/Unknown - 130s 233ms/step - loss: 0.1728 - accuracy: 0.2170 - iou: 0.0252 - dice: 0.0503
# Epoch 1: val_loss improved from inf to 0.10523, saving model to /home/alisa/Models/Planck_Unet/pz-not-cluster_8-8/pz-not-cluster_8-8_ep001.hdf5
# ...
# 554/554 [==============================] - 154s 276ms/step - loss: 0.1728 - accuracy: 0.2170 - iou: 0.0252 - dice: 0.0503 - val_loss: 0.1052 - val_accuracy: 0.0482 - val_iou: 0.0305 - val_dice: 0.0611
# Epoch #1
# Epoch 2/2
#     554/Unknown - 121s 218ms/step - loss: 0.1067 - accuracy: 0.2611 - iou: 0.0339 - dice: 0.0679
# Epoch 2: val_loss improved from 0.10523 to 0.07338, saving model to /home/alisa/Models/Planck_Unet/pz-not-cluster_8-8/pz-not-cluster_8-8_ep002.hdf5
# ...

# %%
name = "pz-flfi_8-8"
dataset = "pz"
old_version = False
model_prms={"equal_filters": True, "input_shape": (64, 64, 9), "n_filters": 8, "n_blocks": 5, "weights": None, "n_classes": 1}
epochs = 140
batch_size = 150
lrdict = None
add_LFI = "/home/alisa/Data/Planck/fake_lfi"
train_Planck_Unet(name, "/home/alisa/Data/Planck/healpix_nside2/", 
                  f"/home/alisa/Data/Planck/datasets/{dataset}/",
                  f"/home/alisa/Models/Planck_Unet/{name}", pixels="default", 
                  batch_size=batch_size, epochs=epochs, device="gpu", continue_train=False, 
                  lr_scheduler=lrdict, save_best_only=True, test_as_val = True, 
                  old_version=old_version, model_prms=model_prms,
                  add_LFI=add_LFI)
# Out:
# /home/alisa/.local/lib/python3.9/site-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch #0
#     572/Unknown - 136s 235ms/step - loss: 0.2148 - accuracy: 0.9591 - iou: 0.0087 - dice: 0.0174
# Epoch 1: val_loss improved from inf to 0.08859, saving model to /home/alisa/Models/Planck_Unet/pz-flfi_8-8/pz-flfi_8-8_ep001.hdf5
# ...
# 572/572 [==============================] - 161s 280ms/step - loss: 0.2148 - accuracy: 0.9591 - iou: 0.0087 - dice: 0.0174 - val_loss: 0.0886 - val_accuracy: 0.9893 - val_iou: 0.0102 - val_dice: 0.0204
# Epoch #1
# Epoch 2/2
#     188/Unknown - 47s 253ms/step - loss: 0.0971 - accuracy: 0.9887 - iou: 0.0104 - dice: 0.0209

# %%
name = "pz-frlfi_8-8"
dataset = "pz"
old_version = False
model_prms={"equal_filters": True, "input_shape": (64, 64, 9), "n_filters": 8, "n_blocks": 5, "weights": None, "n_classes": 1,
           "weights": "/home/alisa/Models/Planck_Unet/pz-flfi_8-8/pz-flfi_8-8_ep136.hdf5"}
epochs = 140
batch_size = 150
lrdict = None
add_LFI = "/home/alisa/Data/Planck/healpix_nside2_lfi/"
train_Planck_Unet(name, "/home/alisa/Data/Planck/healpix_nside2/", 
                  f"/home/alisa/Data/Planck/datasets/{dataset}/",
                  f"/home/alisa/Models/Planck_Unet/{name}", pixels="default", 
                  batch_size=batch_size, epochs=epochs, device="gpu", continue_train=False, 
                  lr_scheduler=lrdict, save_best_only=True, test_as_val = True, 
                  old_version=old_version, model_prms=model_prms,
                  add_LFI=add_LFI)
# Out:
# /home/alisa/.local/lib/python3.9/site-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch #0
#     473/Unknown - 117s 244ms/step - loss: 0.0372 - accuracy: 0.9917 - iou: 0.2134 - dice: 0.4268

# %%
name = "pz-not-cluster-flfi_8-8"
dataset = "pz-not-cluster"
old_version = False
model_prms={"equal_filters": True, "input_shape": (64, 64, 9), "n_filters": 8, "n_blocks": 5, "weights": None, "n_classes": 2}
epochs = 140
batch_size = 150
lrdict = None
add_LFI = "/home/alisa/Data/Planck/fake_lfi/"
train_Planck_Unet(name, "/home/alisa/Data/Planck/healpix_nside2/", 
                  f"/home/alisa/Data/Planck/datasets/{dataset}/",
                  f"/home/alisa/Models/Planck_Unet/{name}", pixels="default", 
                  batch_size=batch_size, epochs=epochs, device="gpu", continue_train=False, 
                  lr_scheduler=lrdict, save_best_only=True, test_as_val = True, 
                  old_version=old_version, model_prms=model_prms,
                  add_LFI=add_LFI)
# Out:
# /home/alisa/.local/lib/python3.9/site-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch #0
#     463/Unknown - 115s 246ms/step - loss: 0.5225 - accuracy: 0.6094 - iou: 0.0280 - dice: 0.0559

# %%
name = "pz-not-cluster-frlfi_8-8"
dataset = "pz-not-cluster"
old_version = False
model_prms={"equal_filters": True, "input_shape": (64, 64, 9), "n_filters": 8, "n_blocks": 5, 
            "weights": 
            "/home/alisa/Models/Planck_Unet/pz-not-cluster-flfi_8-8/pz-not-cluster-flfi_8-8_ep133.hdf5", 
            "n_classes": 2}
epochs = 140
batch_size = 150
lrdict = None
add_LFI = "/home/alisa/Data/Planck/healpix_nside2_lfi/"
train_Planck_Unet(name, "/home/alisa/Data/Planck/healpix_nside2/", 
                  f"/home/alisa/Data/Planck/datasets/{dataset}/",
                  f"/home/alisa/Models/Planck_Unet/{name}", pixels="default", 
                  batch_size=batch_size, epochs=epochs, device="gpu", continue_train=False, 
                  lr_scheduler=lrdict, save_best_only=True, test_as_val = True, 
                  old_version=old_version, model_prms=model_prms,
                  add_LFI=add_LFI)
# Out:
# /home/alisa/.local/lib/python3.9/site-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch #0
#     554/Unknown - 140s 250ms/step - loss: 0.0432 - accuracy: 0.0917 - iou: 0.4553 - dice: 0.9107
# Epoch 1: val_loss improved from inf to 0.03660, saving model to /home/alisa/Models/Planck_Unet/pz-not-cluster-frlfi_8-8/pz-not-cluster-frlfi_8-8_ep001.hdf5
# ...
# 554/554 [==============================] - 168s 302ms/step - loss: 0.0432 - accuracy: 0.0917 - iou: 0.4553 - dice: 0.9107 - val_loss: 0.0366 - val_accuracy: 0.0654 - val_iou: 0.5728 - val_dice: 1.1456
# Epoch #1
# Epoch 2/2
#     554/Unknown - 137s 247ms/step - loss: 0.0370 - accuracy: 0.0706 - iou: 0.5700 - dice: 1.1400
# Epoch 2: val_loss improved from 0.03660 to 0.03441, saving model to /home/alisa/Models/Planck_Unet/pz-not-cluster-frlfi_8-8/pz-not-cluster-frlfi_8-8_ep002.hdf5
# ...

# %%
name = "not-cluster"
dataset = "not-cluster"
old_version = False
model_prms={"equal_filters": True, "input_shape": (64, 64, 9), "n_filters": 8, "n_blocks": 5, "weights": None, "n_classes": 1}
epochs = 140
batch_size = 150
lrdict = None
add_LFI = "/home/alisa/Data/Planck/healpix_nside2_lfi/"
train_Planck_Unet(name, "/home/alisa/Data/Planck/healpix_nside2/", 
                  f"/home/alisa/Data/Planck/datasets/{dataset}/",
                  f"/home/alisa/Models/Planck_Unet/{name}", pixels="default", 
                  batch_size=batch_size, epochs=epochs, device="gpu", continue_train=False, 
                  lr_scheduler=lrdict, save_best_only=True, test_as_val = True, 
                  old_version=old_version, model_prms=model_prms,
                  add_LFI=add_LFI)
# Out:
# /home/alisa/.local/lib/python3.9/site-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch #0
#     571/Unknown - 141s 244ms/step - loss: 0.2457 - accuracy: 0.9373 - iou: 0.0111 - dice: 0.0221
# Epoch 1: val_loss improved from inf to 0.11797, saving model to /home/alisa/Models/Planck_Unet/not-cluster/not-cluster_ep001.hdf5
# ...
# 571/571 [==============================] - 165s 287ms/step - loss: 0.2457 - accuracy: 0.9373 - iou: 0.0111 - dice: 0.0221 - val_loss: 0.1180 - val_accuracy: 0.9852 - val_iou: 0.0091 - val_dice: 0.0182
# Epoch #1
# Epoch 2/2
#     571/Unknown - 142s 248ms/step - loss: 0.1256 - accuracy: 0.9834 - iou: 0.0104 - dice: 0.0209
# Epoch 2: val_loss improved from 0.11797 to 0.09516, saving model to /home/alisa/Models/Planck_Unet/not-cluster/not-cluster_ep002.hdf5
# ...
